# %%
import numpy as np
import tensorflow as tf
from tensorflow import keras
import pandas as pd
from matplotlib import pyplot as plt
# %matplotlib inline

# %%
df = pd.read_csv("MLA_File.csv")
df
# Out:
#       b  Force_coef
# 0  0.10    0.003885
# 1  0.11    0.004385
# 2  0.12    0.004917
# 3  0.13    0.005503
# 4  0.14    0.006149
# 5  0.15    0.006973
# 6  0.16    0.007553
# 7  0.17    0.008382
# 8  0.18    0.009412
# 9  0.19    0.014717

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(df[['b']],df.Force_coef,test_size=0.2, random_state=25)

# %%
X_train_scaled = X_train.copy()
X_train_scaled['b'] = X_train_scaled['b'] / 100

X_test_scaled = X_test.copy()
X_test_scaled['b'] = X_test_scaled['b'] / 100

# %%
model = keras.Sequential([
    keras.layers.Dense(1, input_shape=(1,), activation='sigmoid', kernel_initializer='ones', bias_initializer='zeros')
])

model.compile(optimizer='adam',
              loss='binary_crossentropy',
              metrics=['accuracy'])

model.fit(X_train_scaled, y_train, epochs=5000)
# Out:
# Epoch 1/5000
# 1/1 [==============================] - 0s 283ms/step - loss: 0.6939 - accuracy: 0.0000e+00
# Epoch 2/5000
# 1/1 [==============================] - 0s 2ms/step - loss: 0.6934 - accuracy: 0.0000e+00
# Epoch 3/5000
# 1/1 [==============================] - 0s 3ms/step - loss: 0.6929 - accuracy: 0.0000e+00
# Epoch 4/5000
# 1/1 [==============================] - 0s 2ms/step - loss: 0.6924 - accuracy: 0.0000e+00
# Epoch 5/5000
# 1/1 [==============================] - 0s 3ms/step - loss: 0.6919 - accuracy: 0.0000e+00
# Epoch 6/5000
# 1/1 [==============================] - 0s 4ms/step - loss: 0.6914 - accuracy: 0.0000e+00
# Epoch 7/5000
# 1/1 [==============================] - 0s 2ms/step - loss: 0.6909 - accuracy: 0.0000e+00
# Epoch 8/5000
# 1/1 [==============================] - 0s 4ms/step - loss: 0.6904 - accuracy: 0.0000e+00
# Epoch 9/5000
# 1/1 [==============================] - 0s 3ms/step - loss: 0.6899 - accuracy: 0.0000e+00
# Epoch 10/5000
# ...

# %%
model.evaluate(X_test_scaled,y_test)
# Out:
# 1/1 [==============================] - 0s 64ms/step - loss: 0.0614 - accuracy: 0.0000e+00
# [0.06140384078025818, 0.0]

# %%
X_test
# Out:
#       b
# 5  0.15
# 1  0.11

# %%
y_test
# Out:
# 5    0.006973
# 1    0.004385
# Name: Force_coef, dtype: float64

# %%
model.predict(X_test_scaled)
# Out:
# array([[0.04279688],
#        [0.04283121]], dtype=float32)

# %% [markdown]
# here the value after doing prediction is not matching with the actual value .
# means it requires a lot of changes in the NURAL NETWORK

# %%
coef, intercept = model.get_weights()

# %%
coef, intercept
# Out:
# (array([[-1.9247072]], dtype=float32), array([-2.943835], dtype=float32))

# %% [markdown]
# HERE THE value for w1 = -1.9247 and value for b = -2.943835

# %% [markdown]
# now doing the calculation without tensor flow

# %%
def sigmoid(x):
        import math
        return 1 / (1 + math.exp(-x))
sigmoid(18)
# Out:
# 0.9999999847700205

# %%
def prediction_function(b):
    weighted_sum = coef[0]*b +intercept
    return sigmoid(weighted_sum)

prediction_function(0.15)
# Out:
# 0.03795934163337895

# %%
def sigmoid_numpy(X):
   return 1/(1+np.exp(-X))

# %%
def log_loss(y_true, y_predicted):
    epsilon = 1e-15
    y_predicted_new = [max(i,epsilon) for i in y_predicted]
    y_predicted_new = [min(i,1-epsilon) for i in y_predicted_new]
    y_predicted_new = np.array(y_predicted_new)
    return -np.mean(y_true*np.log(y_predicted_new)+(1-y_true)*np.log(1-y_predicted_new))

# %%
def gradient_descent(b, y_true, epochs, loss_thresold):
    w1 = 1
    bias = 0
    rate = 0.5
    n = len(b)
    for i in range(epochs):
        weighted_sum = w1 * b + bias
        y_predicted = sigmoid_numpy(weighted_sum)
        loss = log_loss(y_true, y_predicted)

        w1d = (1/n)*np.dot(np.transpose(b),(y_predicted-y_true)) 

        bias_d = np.mean(y_predicted-y_true)
        w1 = w1 - rate * w1d
       
        bias = bias - rate * bias_d

        print (f'Epoch:{i}, w1:{w1}, bias:{bias}, loss:{loss}')

        if loss<=loss_thresold:
            break

    return w1, bias

# %%
gradient_descent(X_train_scaled['b'],y_train,5000, 0.0673)
# Out:
# Epoch:0, w1:0.9996338868507628, bias:-0.24640349802425915, loss:0.6938791195147639
# Epoch:1, w1:0.9993133633375308, bias:-0.4621586113000873, loss:0.5800201871377783
# Epoch:2, w1:0.9990317002013238, bias:-0.6517893667291412, loss:0.49259125927111613
# Epoch:3, w1:0.9987826920675654, bias:-0.819467524325142, loss:0.4248699455325349
# Epoch:4, w1:0.9985610016561098, bias:-0.9687812007278621, loss:0.37174744066634424
# Epoch:5, w1:0.9983621987736769, bias:-1.1027086764146254, loss:0.3294795027781232
# Epoch:6, w1:0.9981826663371948, bias:-1.2236815872222015, loss:0.29535966749364784
# Epoch:7, w1:0.9980194675986056, bias:-1.333674193499271, loss:0.2674330443941853
# Epoch:8, w1:0.9978702166237017, bias:-1.4342904580313327, loss:0.24427823373973667
# Epoch:9, w1:0.9977329668949352, bias:-1.526838937538705, loss:0.22485082496669992
# Epoch:10, w1:0.9976061207362764, bias:-1.6123936748484566, loss:0.20837388403373122
# ...

# %%
coef, intercept
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-b13cffd85d76> in <module>
# ----> 1 coef, intercept
#
# NameError: name 'coef' is not defined
